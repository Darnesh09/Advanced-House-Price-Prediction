# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv("/home/darnesh/Documents/programming/Machine Learning/house-prices-advanced-regression-techniques/train.csv")
data.shape
# Out:
# (1460, 81)

# %%
pd.set_option('display.max_columns',None)

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# # Missing values and their relation with the target variable

# %%
nan_features = [features for features in data.columns if data[features].isnull().sum()>1]
for features in nan_features:
    print(f"{features} : {data[features].isnull().sum()}")
# Out:
# LotFrontage : 259
# Alley : 1369
# MasVnrType : 8
# MasVnrArea : 8
# BsmtQual : 37
# BsmtCond : 37
# BsmtExposure : 38
# BsmtFinType1 : 37
# BsmtFinType2 : 38
# FireplaceQu : 690
# GarageType : 81
# GarageYrBlt : 81
# GarageFinish : 81
# GarageQual : 81
# GarageCond : 81
# PoolQC : 1453
# Fence : 1179
# MiscFeature : 1406

# %%
for feature in nan_features:
    df = data.copy()
    df[feature] = np.where(df[feature].isna(),1,0)
    plt.figure(figsize=(5,4))
    df.groupby(feature)['SalePrice'].mean().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# The relation between the missing values and the target variable is meaning full. So missing values should be replaced with values insted of dropping them

# %% [markdown]
# # Numerical variables

# %%
num_features = [feature for feature in data.columns if data[feature].dtypes != object]
data[num_features].head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %% [markdown]
# There are 4 temporal/datetime variables

# %%
year_features = [feature for feature in data.columns if 'Yr' in feature or 'Year' in feature]
year_features
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for feature in year_features:
    print(feature, data[feature].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
data.groupby('YearBuilt')['SalePrice'].mean().plot()
# Out:
# <AxesSubplot:xlabel='YearBuilt'>

# %%
data.groupby('YrSold')['SalePrice'].median().plot()
# Out:
# <AxesSubplot:xlabel='YrSold'>

# %%
for feature in year_features:
    if feature != 'YrSold':
        plt.figure(figsize=(7,5))
        plt.scatter(data['YrSold']-data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.title(feature)
        plt.show()

# %% [markdown]
# <h5>Discrete variables

# %%
dis_features = [feature for feature in num_features if len(data[feature].unique())<25 and feature not in year_features]
dis_features
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
data[dis_features].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
for feature in dis_features:
    data.groupby(feature)['SalePrice'].mean().plot(kind='bar',figsize=(5,4),rot='horizontal')
    plt.title(feature)
    plt.legend()
    plt.show()

# %% [markdown]
# <h5>Continuous features

# %%
con_features = [feature for feature in num_features if feature not in dis_features+year_features+['Id']]
con_features
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
for feature in con_features:
    plt.figure(figsize=(5,4))
    data[feature].hist(bins=25)
    plt.title(feature)
    plt.xlabel(feature)
    plt.ylabel('Counts')
    plt.show()

# %% [markdown]
# the numerical data is not normally distributed, it is skewed, we are using logarithmic transformation

# %%
for feature in con_features:
    df = data.copy()
    if 0 in df[feature].unique():
        pass
    else:
        df[feature] = np.log(df[feature])
        df['SalePrice'] = np.log(df['SalePrice'])
        plt.figure(figsize=(7,4))
        plt.scatter(df['SalePrice'],df[feature])
        plt.xlabel('SalePrice')
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %%
for feature in con_features:
    df = data.copy()
    if 0 in df[feature].unique():
        pass
    else:
        plt.figure(figsize=(7,4))
        plt.scatter(df['SalePrice'],df[feature])
        plt.xlabel('SalePrice')
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %% [markdown]
# The above is without logarithmic tranformation

# %% [markdown]
# # Outliers

# %%
df = data.copy()
for feature in con_features:
    if 0 not in df[feature].unique():
        df[feature] = np.log(df[feature])
        plt.figure(figsize=(7,4))
        df.boxplot(column=feature)
        plt.show()

# %%
df = data.copy()
ls = []
for feature in con_features:
    if 0 not in df[feature].unique():
        ls.append(feature)
        df[feature] = np.log(df[feature])

sns.boxplot(df[ls])
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h5>Categorical features

# %%
cat_features = [feature for feature in data.columns if data[feature].dtypes==object]
cat_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
for feature in cat_features:
    print(f"{feature}  :  {len(data[feature].unique())}")
# Out:
# MSZoning  :  5
# Street  :  2
# Alley  :  3
# LotShape  :  4
# LandContour  :  4
# Utilities  :  2
# LotConfig  :  5
# LandSlope  :  3
# Neighborhood  :  25
# Condition1  :  9
# Condition2  :  8
# BldgType  :  5
# HouseStyle  :  8
# RoofStyle  :  6
# RoofMatl  :  8
# Exterior1st  :  15
# Exterior2nd  :  16
# MasVnrType  :  5
# ExterQual  :  4
# ExterCond  :  5
# Foundation  :  6
# BsmtQual  :  5
# BsmtCond  :  5
# BsmtExposure  :  5
# BsmtFinType1  :  7
# BsmtFinType2  :  7
# Heating  :  6
# HeatingQC  :  5
# CentralAir  :  2
# Electrical  :  6
# KitchenQual  :  4
# Functional  :  7
# FireplaceQu  :  6
# GarageType  :  7
# GarageFinish  :  4
# GarageQual  :  6
# GarageCond  :  6
# PavedDrive  :  3
# PoolQC  :  4
# Fence  :  5
# MiscFeature  :  5
# SaleType  :  9
# SaleCondition  :  6

# %%
for feature in cat_features:
    plt.figure(figsize=(6,4))
    data.groupby(feature)['SalePrice'].mean().plot(kind='bar')
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()
