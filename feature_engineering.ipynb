# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns',None)

# %%
data = pd.read_csv("/home/darnesh/Documents/programming/Machine Learning/house-prices-advanced-regression-techniques/train.csv")
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
test = pd.read_csv("/home/darnesh/Documents/programming/Machine Learning/house-prices-advanced-regression-techniques/test.csv")
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1Story            5            6       1961
# 1       Norm     1Fam     1Story            6            6       1958
# 2       Norm     1Fam     2Story            5            5       1997
# 3       Norm     1Fam     2Story            6            6       1998
# 4       Norm   TwnhsE     1Story            8            5       1992
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          1961     Gable  CompShg     VinylSd     VinylSd       None
# 1          1958       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 2          1998     Gable  CompShg     VinylSd     VinylSd       None
# 3          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 4          1992     Gable  CompShg     HdBoard     HdBoard       None
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0         0.0        TA        TA     CBlock       TA       TA           No
# 1       108.0        TA        TA     CBlock       TA       TA           No
# 2         0.0        TA        TA      PConc       Gd       TA           No
# 3        20.0        TA        TA      PConc       TA       TA           No
# 4         0.0        Gd        TA      PConc       Gd       TA           No
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          Rec       468.0          LwQ       144.0      270.0        882.0
# 1          ALQ       923.0          Unf         0.0      406.0       1329.0
# 2          GLQ       791.0          Unf         0.0      137.0        928.0
# 3          GLQ       602.0          Unf         0.0      324.0        926.0
# 4          ALQ       263.0          Unf         0.0     1017.0       1280.0
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        TA          Y      SBrkr       896         0             0
# 1    GasA        TA          Y      SBrkr      1329         0             0
# 2    GasA        Gd          Y      SBrkr       928       701             0
# 3    GasA        Ex          Y      SBrkr       926       678             0
# 4    GasA        Ex          Y      SBrkr      1280         0             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0        896           0.0           0.0         1         0             2
# 1       1329           0.0           0.0         1         1             3
# 2       1629           0.0           0.0         2         1             3
# 3       1604           0.0           0.0         2         1             3
# 4       1280           0.0           0.0         2         0             2
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          TA             5        Typ           0         NaN
# 1             1          Gd             6        Typ           0         NaN
# 2             1          TA             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             5        Typ           0         NaN
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       1961.0          Unf         1.0       730.0         TA
# 1     Attchd       1958.0          Unf         1.0       312.0         TA
# 2     Attchd       1997.0          Fin         2.0       482.0         TA
# 3     Attchd       1998.0          Fin         2.0       470.0         TA
# 4     Attchd       1992.0          RFn         2.0       506.0         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y         140            0              0          0
# 1         TA          Y         393           36              0          0
# 2         TA          Y         212           34              0          0
# 3         TA          Y         360           36              0          0
# 4         TA          Y           0           82              0          0
#
#    ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0          120         0    NaN  MnPrv         NaN        0       6    2010
# 1            0         0    NaN    NaN        Gar2    12500       6    2010
# 2            0         0    NaN  MnPrv         NaN        0       3    2010
# 3            0         0    NaN    NaN         NaN        0       6    2010
# 4          144         0    NaN    NaN         NaN        0       1    2010
#
#   SaleType SaleCondition
# 0       WD        Normal
# 1       WD        Normal
# 2       WD        Normal
# 3       WD        Normal
# 4       WD        Normal

# %%
cat_features_nan = [feature for feature in data.columns if data[feature].isnull().sum()>0 and data[feature].dtypes==object]
for feature in cat_features_nan:
    print(f"{feature} has {np.round(data[feature].isnull().mean()*100,2)}% of nan values")
# Out:
# Alley has 93.77% of nan values
# MasVnrType has 0.55% of nan values
# BsmtQual has 2.53% of nan values
# BsmtCond has 2.53% of nan values
# BsmtExposure has 2.6% of nan values
# BsmtFinType1 has 2.53% of nan values
# BsmtFinType2 has 2.6% of nan values
# Electrical has 0.07% of nan values
# FireplaceQu has 47.26% of nan values
# GarageType has 5.55% of nan values
# GarageFinish has 5.55% of nan values
# GarageQual has 5.55% of nan values
# GarageCond has 5.55% of nan values
# PoolQC has 99.52% of nan values
# Fence has 80.75% of nan values
# MiscFeature has 96.3% of nan values

# %%
for feature in cat_features_nan:
    data[feature] = data[feature].fillna('Missing')
    test[feature] = test[feature].fillna('Missing')

# %%
data[cat_features_nan].sample(5)
# Out:
#         Alley MasVnrType BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 796   Missing    BrkFace       TA       TA           No          Unf
# 928   Missing       None       Gd       TA           Av          Unf
# 952   Missing       None       Gd       TA           Av          GLQ
# 676      Grvl       None       TA       Fa           No          Unf
# 1278  Missing    Missing       Gd       TA           No          GLQ
#
#      BsmtFinType2 Electrical FireplaceQu GarageType GarageFinish GarageQual  \
# 796           Unf      SBrkr          TA     Attchd          RFn         TA
# 928           Unf      SBrkr          TA     Attchd          RFn         TA
# 952           Unf      SBrkr     Missing     Detchd          Fin         TA
# 676           Unf      SBrkr     Missing     2Types          Unf         Fa
# 1278          Unf      SBrkr          Gd     Attchd          RFn         TA
#
#      GarageCond   PoolQC    Fence MiscFeature
# 796          TA  Missing    MnPrv     Missing
# 928          TA  Missing  Missing     Missing
# 952          TA  Missing    MnPrv     Missing
# 676          Fa  Missing  Missing     Missing
# 1278         TA  Missing  Missing     Missing

# %%
num_feature_nan = [feature for feature in data.columns if data[feature].isnull().sum()>0 and data[feature].dtypes!=object]
for feature in num_feature_nan:
    print(f"{feature} has {np.round(data[feature].isnull().mean()*100,2)}% of nan values")
# Out:
# LotFrontage has 17.74% of nan values
# MasVnrArea has 0.55% of nan values
# GarageYrBlt has 5.55% of nan values

# %%
for feature in num_feature_nan:
    data[feature+'_nan'] = np.where(data[feature].isna(),1,0)
    data[feature].fillna(data[feature].median(),inplace=True)

for feature in ['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageArea']:
    test[feature] = test[feature].median()

data[num_feature_nan]
# Out:
#       LotFrontage  MasVnrArea  GarageYrBlt
# 0            65.0       196.0       2003.0
# 1            80.0         0.0       1976.0
# 2            68.0       162.0       2001.0
# 3            60.0         0.0       1998.0
# 4            84.0       350.0       2000.0
# ...           ...         ...          ...
# 1455         62.0         0.0       1999.0
# 1456         85.0       119.0       1978.0
# 1457         66.0         0.0       1941.0
# 1458         68.0         0.0       1950.0
# 1459         75.0         0.0       1965.0
#
# [1460 rows x 3 columns]

# %%
data.sample(6)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley  \
# 1109  1110          20       RL        107.0    11362   Pave  Missing
# 847    848          20       RL         36.0    15523   Pave  Missing
# 419    420          20       RL         65.0     8450   Pave  Missing
# 1195  1196          60       RL         51.0     8029   Pave  Missing
# 23      24         120       RM         44.0     4224   Pave  Missing
# 829    830         160       FV         24.0     2544   Pave     Pave
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 1109      IR1         Lvl    AllPub    Inside       Gtl      NridgHt
# 847       IR1         Lvl    AllPub   CulDSac       Gtl      CollgCr
# 419       Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 1195      IR1         Lvl    AllPub    Inside       Gtl      Gilbert
# 23        Reg         Lvl    AllPub    Inside       Gtl      MeadowV
# 829       Reg         Lvl    AllPub    Inside       Gtl      Somerst
#
#      Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 1109       Norm       Norm     1Fam     1Story            8            5
# 847        Norm       Norm     1Fam     1Story            5            6
# 419        Norm       Norm     1Fam     1Story            5            6
# 1195       Norm       Norm     1Fam     2Story            6            5
# 23         Norm       Norm   TwnhsE     1Story            5            7
# 829        Norm       Norm    Twnhs     2Story            7            5
#
#       YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# 1109       2004          2005     Gable  CompShg     MetalSd     MetalSd
# 847        1972          1972     Gable  CompShg     HdBoard     Plywood
# 419        1968          1968     Gable  CompShg     VinylSd     VinylSd
# 1195       2005          2005     Gable  CompShg     VinylSd     VinylSd
# 23         1976          1976     Gable  CompShg     CemntBd     CmentBd
# 829        2005          2005     Gable  CompShg     MetalSd     MetalSd
#
#      MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1109      Stone        42.0        Gd        TA      PConc       Ex       TA
# 847        None         0.0        TA        TA     CBlock       TA       TA
# 419        None         0.0        TA        TA     CBlock       TA       TA
# 1195       None         0.0        TA        TA      PConc       Gd       TA
# 23         None         0.0        TA        TA      PConc       Gd       TA
# 829        None         0.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1109           Mn          GLQ        1039          Unf           0
# 847            Av          BLQ         460          Unf           0
# 419            No          BLQ         775          Unf           0
# 1195           No          Unf           0          Unf           0
# 23             No          GLQ         840          Unf           0
# 829            No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1109        797         1836    GasA        Ex          Y      SBrkr
# 847         404          864    GasA        Ex          Y      SBrkr
# 419         281         1056    GasA        Ex          Y      SBrkr
# 1195        728          728    GasA        Ex          Y      SBrkr
# 23          200         1040    GasA        TA          Y      SBrkr
# 829         600          600    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1109      1836         0             0       1836             1             0
# 847        864         0             0        864             1             0
# 419       1056         0             0       1056             1             0
# 1195       728       728             0       1456             0             0
# 23        1060         0             0       1060             1             0
# 829        520       623            80       1223             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1109         2         0             3             1          Gd
# 847          1         0             3             1          TA
# 419          1         0             3             1          TA
# 1195         2         1             3             1          Gd
# 23           1         0             3             1          TA
# 829          2         1             2             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1109             7        Typ           1          Gd     Attchd       2004.0
# 847              5        Typ           1          Fa     Attchd       1972.0
# 419              6        Typ           1          Fa     Attchd       1968.0
# 1195             8        Typ           0     Missing     Attchd       2005.0
# 23               6        Typ           1          TA     Attchd       1976.0
# 829              4        Typ           0     Missing     Detchd       2005.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1109          Fin           3         862         TA         TA          Y
# 847           Unf           1         338         TA         TA          Y
# 419           Unf           1         304         TA         TA          Y
# 1195          Fin           2         400         TA         TA          Y
# 23            Unf           2         572         TA         TA          Y
# 829           RFn           2         480         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1109         125          185              0          0            0
# 847            0            0              0          0            0
# 419            0           85            184          0            0
# 1195         100           24              0          0            0
# 23           100          110              0          0            0
# 829            0          166              0          0            0
#
#       PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 1109         0  Missing  Missing     Missing        0       3    2009
# 847          0  Missing  Missing     Missing        0       8    2009
# 419          0  Missing  Missing     Missing        0       7    2010
# 1195         0  Missing  Missing     Missing        0       7    2008
# 23           0  Missing  Missing     Missing        0       6    2007
# 829          0  Missing  Missing     Missing        0       7    2006
#
#      SaleType SaleCondition  SalePrice  LotFrontage_nan  MasVnrArea_nan  \
# 1109       WD        Normal     280000                0               0
# 847        WD        Normal     133500                0               0
# 419        WD        Normal     142000                0               0
# 1195       WD        Normal     176000                0               0
# 23         WD        Normal     129900                0               0
# 829        WD        Normal     147400                0               0
#
#       GarageYrBlt_nan
# 1109                0
# 847                 0
# 419                 0
# 1195                0
# 23                  0
# 829                 0

# %% [markdown]
# another way to impute missing values using sklearn's SimpleImputer is given below

# %%
df = data.copy()
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='median')
df[num_feature_nan] = imputer.fit_transform(df[num_feature_nan])
df[num_feature_nan]
# Out:
#       LotFrontage  MasVnrArea  GarageYrBlt
# 0            65.0       196.0       2003.0
# 1            80.0         0.0       1976.0
# 2            68.0       162.0       2001.0
# 3            60.0         0.0       1998.0
# 4            84.0       350.0       2000.0
# ...           ...         ...          ...
# 1455         62.0         0.0       1999.0
# 1456         85.0       119.0       1978.0
# 1457         66.0         0.0       1941.0
# 1458         68.0         0.0       1950.0
# 1459         75.0         0.0       1965.0
#
# [1460 rows x 3 columns]

# %%
imputer.statistics_
# Out:
# array([  69.,    0., 1980.])

# %% [markdown]
# when we have many outliers we should replace them with median or mode but not with mean

# %%
for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
    data[feature] = data['YrSold']-data[feature]
    test[feature] = test['YrSold']-test[feature]

data[['YearBuilt','YearRemodAdd','GarageYrBlt']].sample(6)
# Out:
#       YearBuilt  YearRemodAdd  GarageYrBlt
# 664           1             0          1.0
# 815          12            12         12.0
# 692          17            16         17.0
# 275          84             2         31.0
# 1402          0             0          0.0
# 1359          2             1          2.0

# %%
temp = data.groupby('KitchenQual')['SalePrice'].count()/len(data)
temp
# Out:
# KitchenQual
# Ex    0.068493
# Fa    0.026712
# Gd    0.401370
# TA    0.503425
# Name: SalePrice, dtype: float64

# %%
temp_df = temp[temp>0.03].index
temp_df
# Out:
# Index(['Ex', 'Gd', 'TA'], dtype='object', name='KitchenQual')

# %%
# numerical features with all non zero values
for feature in ['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']:
    data[feature] = np.log(data[feature])

data[['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']].sample(6)
# Out:
#       LotFrontage   LotArea  1stFlrSF  GrLivArea  SalePrice
# 983      4.234107  9.328123  7.046647   7.736307  12.452542
# 306      4.753590  9.508517  7.022868   7.715570  12.323856
# 1187     4.488636  9.430359  7.392648   7.392648  12.476100
# 1201     4.382027  9.249561  6.763885   7.483807  12.195517
# 910      4.382027  9.358760  7.007601   7.729296  11.946654
# 883      4.094345  8.732950  6.860664   7.709757  11.682668

# %%
for feature in ['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea']:
    test[feature] = np.log(test[feature])

# %% [markdown]
# ## Handling rare categorical features
# remove categorical variables that are present less than 1% in the observation

# %%
cat_features = [feature for feature in data.columns if data[feature].dtypes=='object']
cat_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
for feature in cat_features:
    temp = data.groupby(feature)['SalePrice'].count()/len(data)
    temp = temp[temp>0.01].index
    data[feature] = np.where(data[feature].isin(temp),data[feature],'Rare_val')

    temp_test = test.groupby(feature).count()/len(test)
    temp_test = temp_test[temp_test>0.01].index
    test[feature] = np.where(test[feature].isin(temp_test),test[feature],'Rare_val')

# %%
data[cat_features].sample(6)
# Out:
#      MSZoning Street    Alley LotShape LandContour Utilities LotConfig  \
# 433        RL   Pave  Missing      IR1         Lvl    AllPub    Corner
# 1451       RL   Pave  Missing      Reg         Lvl    AllPub    Inside
# 295        RL   Pave  Missing      IR1         Lvl    AllPub   CulDSac
# 1046       RL   Pave  Missing      IR1         Lvl    AllPub    Inside
# 895        RL   Pave  Missing      Reg         Lvl    AllPub    Inside
# 1053       RL   Pave  Missing      Reg         Lvl    AllPub    Inside
#
#      LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 433        Gtl      Gilbert       Norm       Norm     1Fam     2Story
# 1451       Gtl      Somerst       Norm       Norm     1Fam     1Story
# 295        Gtl      Mitchel       Norm       Norm     1Fam       SLvl
# 1046       Gtl      StoneBr       Norm       Norm     1Fam     2Story
# 895        Gtl        NAmes       Norm       Norm     1Fam     2Story
# 1053       Mod      Edwards       Norm       Norm     1Fam     1Story
#
#      RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual  \
# 433      Gable  CompShg     VinylSd     VinylSd       None        TA
# 1451     Gable  CompShg     CemntBd     CmentBd      Stone        Gd
# 295      Gable  CompShg     HdBoard     HdBoard       None        TA
# 1046       Hip  CompShg     CemntBd     CmentBd      Stone        Gd
# 895        Hip  CompShg     HdBoard     HdBoard    BrkFace        TA
# 1053       Hip  CompShg     HdBoard     HdBoard      Stone        TA
#
#      ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 433         TA      PConc       Gd       TA           No          Unf
# 1451        TA      PConc       Gd       TA           No          Unf
# 295         TA     CBlock       TA       TA           Av          GLQ
# 1046        TA      PConc       Ex       TA           Av          GLQ
# 895         TA     CBlock       TA       TA           No          BLQ
# 1053        TA     CBlock       TA       TA           Av          Rec
#
#      BsmtFinType2 Heating HeatingQC CentralAir Electrical KitchenQual  \
# 433           Unf    GasA        Ex          Y      SBrkr          TA
# 1451          Unf    GasA        Ex          Y      SBrkr          Ex
# 295           Unf    GasA        TA          Y      SBrkr          TA
# 1046          Unf    GasA        Ex          Y      SBrkr          Ex
# 895           Unf    GasA        TA          Y      SBrkr          TA
# 1053          Unf    GasA        Ex          Y      FuseA          TA
#
#      Functional FireplaceQu GarageType GarageFinish GarageQual GarageCond  \
# 433         Typ          TA     Attchd          Fin         TA         TA
# 1451        Typ          Gd     Attchd          Fin         TA         TA
# 295         Typ     Missing     Detchd          Unf         TA         TA
# 1046        Typ          Gd    BuiltIn          Fin         TA         TA
# 895         Typ          TA     Attchd          RFn         TA         TA
# 1053       Min2          Gd    Basment          Unf         TA         TA
#
#      PavedDrive   PoolQC    Fence MiscFeature SaleType SaleCondition
# 433           Y  Missing  Missing     Missing       WD        Normal
# 1451          Y  Missing  Missing     Missing      New       Partial
# 295           Y  Missing    GdPrv     Missing       WD        Normal
# 1046          Y  Missing  Missing     Missing      New       Partial
# 895           Y  Missing  Missing     Missing       WD        Normal
# 1053          Y  Missing  Missing     Missing       WD        Normal

# %%
for feature in cat_features:
    order = data.groupby(feature)['SalePrice'].mean().sort_values().index
    order_value = {k:i for i,k in enumerate(order)}
    data[feature] = data[feature].map(order_value)


    order_test = test.groupby(feature)['SaleCondition'].count().sort_values().index
    order_value_test = {k:i for i,k in enumerate(order_test)}
    test[feature] = test[feature].map(order_value_test)


data.sample(5)
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 414    415          60         3     4.077537  9.326166       1      2
# 1431  1432         120         3     4.234107  8.502689       1      2
# 1267  1268          20         3     4.488636  9.489032       1      2
# 1349  1350          70         1     3.912023  8.565983       1      1
# 1060  1061         120         3     3.713572  8.501064       1      2
#
#       LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# 414          3            1          1          4          0            10
# 1431         1            1          1          0          0            11
# 1267         1            3          1          0          0            19
# 1349         0            1          1          0          0             4
# 1060         0            1          1          0          0            20
#
#       Condition1  Condition2  BldgType  HouseStyle  OverallQual  OverallCond  \
# 414            2           1         3           5            7            5
# 1431           2           1         4           3            6            6
# 1267           2           1         3           3            9            5
# 1349           2           1         3           5            8            5
# 1060           2           1         4           3            8            5
#
#       YearBuilt  YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  \
# 414          15            15          0         0           10           10
# 1431         33            33          0         0            7            7
# 1267          2             1          2         0            5            9
# 1349        136            21          0         0            4            3
# 1060          9             9          0         0            9            9
#
#       MasVnrType  MasVnrArea  ExterQual  ExterCond  Foundation  BsmtQual  \
# 414            1         0.0          2          3           4         3
# 1431           1         0.0          1          3           2         3
# 1267           1         0.0          3          3           4         4
# 1349           1         0.0          1          2           1         2
# 1060           1         0.0          2          3           4         3
#
#       BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  \
# 414          3             1             2          50             4
# 1431         3             1             3         958             5
# 1267         3             4             5           0             5
# 1349         2             1             3         259             5
# 1060         3             2             6         616             5
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  Heating  HeatingQC  CentralAir  \
# 414          531        499         1080        2          4           1
# 1431           0          0          958        2          2           1
# 1267           0       2002         2002        2          4           1
# 1349           0        425          684        0          1           0
# 1060           0        722         1338        2          4           1
#
#       Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 414            3  6.984716      1017             0   7.648263             0
# 1431           3  6.864848         0             0   6.864848             0
# 1267           3  7.609862         0             0   7.609862             0
# 1349           3  6.843750      1215           205   7.765569             0
# 1060           3  7.198931         0             0   7.198931             1
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 414              1         2         1             3             1
# 1431             0         2         0             2             1
# 1267             0         2         0             3             1
# 1349             0         2         0             4             1
# 1060             0         2         0             2             1
#
#       KitchenQual  TotRmsAbvGrd  Functional  Fireplaces  FireplaceQu  \
# 414             2             9           4           1            3
# 1431            1             5           4           0            1
# 1267            3            10           4           1            4
# 1349            1             8           4           0            1
# 1060            2             6           4           0            1
#
#       GarageType  GarageYrBlt  GarageFinish  GarageCars  GarageArea  \
# 414            4         15.0             1           3         678
# 1431           4         33.0             2           2         440
# 1267           4          1.0             3           3         746
# 1349           0         28.0             0           0           0
# 1060           4          9.0             3           2         582
#
#       GarageQual  GarageCond  PavedDrive  WoodDeckSF  OpenPorchSF  \
# 414            2           3           2         196          187
# 1431           2           3           2           0           60
# 1267           2           3           2         144           76
# 1349           0           0           2           0           54
# 1060           2           3           2           0            0
#
#       EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  PoolQC  Fence  \
# 414               0          0            0         0       0      4
# 1431              0          0            0         0       0      4
# 1267              0          0            0         0       0      4
# 1349             20          0            0         0       0      4
# 1060            170          0            0         0       0      4
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# 414             2        0      12    2008         2              3
# 1431            2        0      10    2009         2              3
# 1267            2        0       5    2010         2              3
# 1349            2        0      12    2008         2              3
# 1060            2        0       4    2010         2              3
#
#       SalePrice  LotFrontage_nan  MasVnrArea_nan  GarageYrBlt_nan
# 414   12.337101                0               0                0
# 1431  11.875831                1               0                0
# 1267  12.843971                0               0                0
# 1349  11.711776                0               0                1
# 1060  12.271392                0               0                0

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

feature_scale = [feature for feature in data.columns if feature not in ['Id','SalePrice'] and feature not in cat_features]

scaled = scaler.fit_transform(data[feature_scale])

data[feature_scale] = scaled

data.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0   1    0.235294         3     0.418208  0.366344       1      2         0
# 1   2    0.000000         3     0.495064  0.391317       1      2         0
# 2   3    0.235294         3     0.434909  0.422359       1      2         1
# 3   4    0.294118         3     0.388581  0.390295       1      2         1
# 4   5    0.235294         3     0.513123  0.468761       1      2         1
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0            1          1          0          0            14           2
# 1            1          1          2          0            11           1
# 2            1          1          0          0            14           2
# 3            1          1          1          0            16           2
# 4            1          1          2          0            22           2
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0           1         3           5     0.666667        0.500   0.036765
# 1           1         3           3     0.555556        0.875   0.227941
# 2           1         3           5     0.666667        0.500   0.051471
# 3           1         3           5     0.666667        0.500   0.669118
# 4           1         3           5     0.777778        0.500   0.058824
#
#    YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# 0      0.098361          0         0           10           10           2
# 1      0.524590          0         0            4            3           1
# 2      0.114754          0         0           10           10           2
# 3      0.606557          0         0            2            4           1
# 4      0.147541          0         0           10           10           2
#
#    MasVnrArea  ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  \
# 0     0.12250          2          3           4         3         3
# 1     0.00000          1          3           2         3         3
# 2     0.10125          2          3           4         3         3
# 3     0.00000          1          3           1         2         4
# 4     0.21875          2          3           4         3         3
#
#    BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  BsmtFinSF2  \
# 0             1             6    0.125089             5         0.0
# 1             4             4    0.173281             5         0.0
# 2             2             6    0.086109             5         0.0
# 3             1             4    0.038271             5         0.0
# 4             3             6    0.116052             5         0.0
#
#    BsmtUnfSF  TotalBsmtSF  Heating  HeatingQC  CentralAir  Electrical  \
# 0   0.064212     0.140098        2          4           1           3
# 1   0.121575     0.206547        2          4           1           3
# 2   0.185788     0.150573        2          4           1           3
# 3   0.231164     0.123732        2          3           1           3
# 4   0.209760     0.187398        2          4           1           3
#
#    1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0  0.356155  0.413559           0.0   0.577712      0.333333           0.0
# 1  0.503056  0.000000           0.0   0.470245      0.000000           0.5
# 2  0.383441  0.419370           0.0   0.593095      0.333333           0.0
# 3  0.399941  0.366102           0.0   0.579157      0.333333           0.0
# 4  0.466237  0.509927           0.0   0.666523      0.333333           0.0
#
#    FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  KitchenQual  TotRmsAbvGrd  \
# 0  0.666667       0.5         0.375      0.333333            2      0.500000
# 1  0.666667       0.0         0.375      0.333333            1      0.333333
# 2  0.666667       0.5         0.375      0.333333            2      0.333333
# 3  0.333333       0.0         0.375      0.333333            2      0.416667
# 4  0.666667       0.5         0.500      0.333333            2      0.583333
#
#    Functional  Fireplaces  FireplaceQu  GarageType  GarageYrBlt  GarageFinish  \
# 0           4    0.000000            1           4     0.046729             2
# 1           4    0.333333            3           4     0.289720             2
# 2           4    0.333333            3           4     0.065421             2
# 3           4    0.333333            4           2     0.074766             1
# 4           4    0.333333            3           4     0.074766             2
#
#    GarageCars  GarageArea  GarageQual  GarageCond  PavedDrive  WoodDeckSF  \
# 0        0.50    0.386460           2           3           2    0.000000
# 1        0.50    0.324401           2           3           2    0.347725
# 2        0.50    0.428773           2           3           2    0.000000
# 3        0.75    0.452750           2           3           2    0.000000
# 4        0.75    0.589563           2           3           2    0.224037
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  PoolQC  \
# 0     0.111517       0.000000        0.0          0.0       0.0       0
# 1     0.000000       0.000000        0.0          0.0       0.0       0
# 2     0.076782       0.000000        0.0          0.0       0.0       0
# 3     0.063985       0.492754        0.0          0.0       0.0       0
# 4     0.153565       0.000000        0.0          0.0       0.0       0
#
#    Fence  MiscFeature  MiscVal    MoSold  YrSold  SaleType  SaleCondition  \
# 0      4            2      0.0  0.090909    0.50         2              3
# 1      4            2      0.0  0.363636    0.25         2              3
# 2      4            2      0.0  0.727273    0.50         2              3
# 3      4            2      0.0  0.090909    0.00         2              0
# 4      4            2      0.0  1.000000    0.50         2              3
#
#    SalePrice  LotFrontage_nan  MasVnrArea_nan  GarageYrBlt_nan
# 0  12.247694              0.0             0.0              0.0
# 1  12.109011              0.0             0.0              0.0
# 2  12.317167              0.0             0.0              0.0
# 3  11.849398              0.0             0.0              0.0
# 4  12.429216              0.0             0.0              0.0

# %%
scaler_test = MinMaxScaler()

feature_scale_test = [feature for feature in test.columns if feature not in ['Id','SalePrice'] and feature not in cat_features]

scaled = scaler.fit_transform(test[feature_scale_test])

test[feature_scale_test] = scaled

# %%
test.sample(6)
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 935   2396    0.000000         5          NaN  0.560644       1      2
# 276   1737    0.000000         5          NaN  0.648325       1      2
# 1121  2582    0.058824         2     0.465802  0.387988       1      2
# 1324  2785    0.176471         4     0.384907  0.385263       1      2
# 886   2347    0.000000         3     0.564810  0.496326       1      2
# 1034  2495    0.000000         5     0.615093  0.683254       1      2
#
#       LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# 935          2            3          1          4          2            24
# 276          2            0          1          4          2             2
# 1121         3            3          1          4          2            13
# 1324         3            3          1          4          2            23
# 886          3            3          1          4          2            21
# 1034         3            3          1          4          2            20
#
#       Condition1  Condition2  BldgType  HouseStyle  OverallQual  OverallCond  \
# 935            8           4         4           6     0.555556        0.500
# 276            8           4         4           6     0.777778        0.875
# 1121           8           4         4           6     0.444444        1.000
# 1324           8           4         4           4     0.444444        0.750
# 886            8           4         4           6     0.666667        0.500
# 1034           7           4         4           6     0.333333        0.500
#
#       YearBuilt  YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  \
# 935    0.338462      0.725806          5         3           10           11
# 276    0.230769      0.500000          5         3           13           15
# 1121   0.600000      0.032258          4         3           12           14
# 1324   0.638462      0.935484          5         3           12           14
# 886    0.015385      0.032258          5         3           13           15
# 1034   0.476923      0.951613          5         3           10           12
#
#       MasVnrType  MasVnrArea  ExterQual  ExterCond  Foundation  BsmtQual  \
# 935            3    0.164341          3          4           4         4
# 276            3    0.089147          2          3           4         3
# 1121           4    0.000000          2          4           3         4
# 1324           3    0.112403          3          3           5         4
# 886            4    0.000000          2          4           5         3
# 1034           4    0.000000          3          4           4         4
#
#       BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  \
# 935          4             4             4         0.0             5
# 276          2             2             4         0.0             5
# 1121         4             4             4         0.0             6
# 1324         4             4             5         0.0             6
# 886          4             4             5         0.0             6
# 1034         4             4             5         0.0             6
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  Heating  HeatingQC  CentralAir  \
# 935          0.0        0.0          0.0        3          3           1
# 276          0.0        0.0          0.0        3          2           1
# 1121         0.0        0.0          0.0        3          4           1
# 1324         0.0        0.0          0.0        3          4           1
# 886          0.0        0.0          0.0        3          4           1
# 1034         0.0        0.0          0.0        3          3           0
#
#       Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 935            3  0.481429  0.000000           0.0   0.481429           0.0
# 276            3  0.632741  0.000000           0.0   0.632741           0.0
# 1121           3  0.356102  0.000000           0.0   0.356102           0.0
# 1324           3  0.275246  0.402793           0.0   0.533185           0.0
# 886            3  0.470035  0.000000           0.0   0.470035           0.0
# 1034           3  0.441463  0.000000           0.0   0.441463           0.0
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 935            0.0      0.25       0.0      0.500000           0.5
# 276            0.0      0.50       0.0      0.333333           0.5
# 1121           0.0      0.25       0.0      0.333333           0.5
# 1324           0.0      0.25       0.5      0.833333           0.5
# 886            0.0      0.50       0.0      0.500000           0.5
# 1034           0.0      0.25       0.0      0.333333           0.5
#
#       KitchenQual  TotRmsAbvGrd  Functional  Fireplaces  FireplaceQu  \
# 935             4      0.333333           7        0.25            3
# 276             3      0.250000           3        0.50            4
# 1121            3      0.166667           7        0.00            5
# 1324            3      0.333333           7        0.00            5
# 886             3      0.250000           7        0.00            5
# 1034            4      0.083333           4        0.00            5
#
#       GarageType  GarageYrBlt  GarageFinish  GarageCars  GarageArea  \
# 935            6     0.773885             2         0.2         0.0
# 276            6     0.729299             2         0.6         0.0
# 1121           5     0.882166             3         0.2         0.0
# 1324           5     0.732484             3         0.4         0.0
# 886            6     0.636943             2         0.4         0.0
# 1034           6     0.831210             3         0.2         0.0
#
#       GarageQual  GarageCond  PavedDrive  WoodDeckSF  OpenPorchSF  \
# 935            4           5           2    0.000000     0.037736
# 276            4           5           2    0.324438     0.000000
# 1121           4           2           1    0.108146     0.000000
# 1324           4           5           2    0.016854     0.000000
# 886            4           5           2    0.000000     0.283019
# 1034           4           5           1    0.000000     0.000000
#
#       EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  PoolQC  Fence  \
# 935        0.083004   0.000000          0.0       0.0       2      3
# 276        0.000000   0.708333          0.0       0.0       2      3
# 1121       0.041502   0.238889          0.0       0.0       2      4
# 1324       0.292490   0.000000          0.0       0.0       2      3
# 886        0.000000   0.000000          0.0       0.0       2      4
# 1034       0.000000   0.000000          0.0       0.0       2      4
#
#       MiscFeature  MiscVal    MoSold  YrSold  SaleType  SaleCondition
# 935             3      0.0  0.636364    0.25         9              5
# 276             3      0.0  0.272727    0.75         9              5
# 1121            3      0.0  0.909091    0.25         9              5
# 1324            3      0.0  0.636364    0.00         9              5
# 886             3      0.0  0.454545    0.25         8              4
# 1034            3      0.0  0.545455    0.25         9              5

# %%
data.to_csv("/home/darnesh/Documents/programming/Machine Learning/house-prices-advanced-regression-techniques/featured_train.csv",index=False)
test.to_csv("/home/darnesh/Documents/programming/Machine Learning/house-prices-advanced-regression-techniques/featured_test.csv",index=False)
